# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
spark.conf.set("spark.sql.parquet.vorder.enabled", "true")
spark.conf.set("spark.microsoft.delta.optimizeWrite.enabled","true")
spark.conf.set("spark.microsoft.delta.optimizeWrite.binSize","1073741824")
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 3, Finished, Available, Finished)

# %%
from notebookutils import mssparkutils
adventureWorksPath = "<ENTER HERE>"

file_list = mssparkutils.fs.ls(adventureWorksPath)

# Read each file and create a DataFrame
for file_path in file_list:
    print(file_path)
    df = spark.read.format("csv").options(inferSchema="true", header="true").load(path=f"{file_path.path}*")
    # You can process the DataFrame or register it as a table here
    # For example, to create a temporary table:
    df.createOrReplaceTempView(file_path.name.removesuffix('.csv').replace('.',''))
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 4, Finished, Available, Finished)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTAddress.csv, name=SalesLTAddress.csv, size=62730)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTCustomer.csv, name=SalesLTCustomer.csv, size=218834)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTCustomerAddress.csv, name=SalesLTCustomerAddress.csv, size=37652)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTProduct.csv, name=SalesLTProduct.csv, size=1358363)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTProductCategory.csv, name=SalesLTProductCategory.csv, size=3456)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTProductDescription.csv, name=SalesLTProductDescription.csv, size=148244)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTProductModel.csv, name=SalesLTProductModel.csv, size=25622)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTProductModelProductDescription.csv, name=SalesLTProductModelProductDescription.csv, size=63331)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTSalesOrderDetail.csv, name=SalesLTSalesOrderDetail.csv, size=60667)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTSalesOrderHeader.csv, name=SalesLTSalesOrderHeader.csv, size=9331)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTvGetAllCategories.csv, name=SalesLTvGetAllCategories.csv, size=1113)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTvProductAndDescription.csv, name=SalesLTvProductAndDescription.csv, size=425470)
# FileInfo(path=abfss://6ad8320c-5790-41f4-a857-5d26b0596208@onelake.dfs.fabric.microsoft.com/f33bb547-04df-4b5f-b40c-675f4ba5c610/Files/Adventureworks/SalesLTvProductModelCatalogDescription.csv, name=SalesLTvProductModelCatalogDescription.csv, size=5700)

# %%
# %%sql
#
# <ENTER HERE>
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 5, Finished, Available, Finished)
# <Spark SQL result set with 13 rows and 3 fields>

# %%
# %%sql
#
# <ENTER HERE>
# Out:
# StatementMeta(, f3bd1041-69ec-4442-8ec2-097a6a7a40b7, 8, Finished, Available, Finished)
# <Spark SQL result set with 100 rows and 9 fields>

# %%
views =  <ENTER HERE>
display(views)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ea1db538-0b1e-4957-a824-04707391b4e2)

# %% [markdown]
# # Read Temp Views, clean the data, load into Spark Dataframes
# - Filter Rows
# - Rename Columns
# - Drop Columns

# %%
df_salesltsalesorderdetail = spark.sql("SELECT SalesOrderID, OrderQty, ProductID,UnitPrice, UnitPriceDIscount, LineTotal FROM salesltsalesorderdetail")
display(df_salesltsalesorderdetail)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 6af0ab05-6882-427b-a557-df6f996f3321)

# %%
df_salesltsalesorderheader = spark.sql("SELECT SalesOrderID, RevisionNumber, OrderDate, DueDate, ShipDate, Status, OnlineOrderFlag, SalesOrderNumber, PurchaseOrderNumber, AccountNumber, CustomerID, ShipToAddressID, BillToAddressID, ShipMethod, SubTotal, TaxAmt, Freight, TotalDue FROM salesltsalesorderheader")
display(df_salesltsalesorderheader)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, a0cd822d-ec00-48b6-a0ac-06a7f24604ea)

# %%
# Randomizing the dates in the OrderDate column since our toy AdventureWorks LT dataset only has one distinct order date.
from pyspark.sql.functions import rand, col, expr
df_salesltsalesorderheader = df_salesltsalesorderheader.drop("OrderDate").withColumn("OrderDate", expr("date_add(current_date()-1000, CAST(rand() * 365 AS INT))"))
display(df_salesltsalesorderheader)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 60863e37-935c-4640-89a1-b04504037e01)

# %%
df_salesltcustomer = spark.sql("SELECT CustomerID, Title, FirstName, MiddleName, LastName, Suffix, CompanyName, EmailAddress, Phone  FROM salesltcustomer")
display(df_salesltcustomer)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 86e0f96b-6786-48b0-b148-7070f817924d)

# %%
df_salesltcustomeraddress = spark.sql("SELECT CustomerID, AddressID, AddressType FROM salesltcustomeraddress")
display(df_salesltcustomeraddress)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 80baa6a4-2df8-43d9-9e82-bc26de8f68b4)

# %%
df_salesltproduct = spark.sql("SELECT ProductID, Name, ProductNumber, Color, StandardCost, ListPrice, Size, Weight, ProductCategoryID FROM salesltproduct")
display(df_salesltproduct)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 13, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 898861d4-5bba-4f52-94d8-d528cb6f0195)

# %%
df_salesltproductcategory = spark.sql("SELECT ProductCategoryID, ParentProductCategoryID, Name FROM salesltproductcategory")
display(df_salesltproductcategory)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 14, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4c348c90-e396-487b-bf79-ce589acd2175)

# %% [markdown]
# # Write Data Frames into Silver Lakehouse as Delta Tables

# %%
basePathSilverLakeHouse = "<ENTER HERE>"
tableName="salesOrderHeader"
df_salesltsalesorderheader.write.mode("overwrite").format("delta").save(basePathSilverLakeHouse + '//' + tableName)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 15, Finished, Available, Finished)

# %%
tableName="salesOrderDetail"
df_salesltsalesorderdetail.write.mode("overwrite").format("delta").save(basePathSilverLakeHouse + '//' + tableName)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 16, Finished, Available, Finished)

# %%
tableName="salesCustomer"
df_salesltcustomer.write.mode("overwrite").format("delta").save(basePathSilverLakeHouse + '//' + tableName)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 17, Finished, Available, Finished)

# %%
tableName="salesCustomerAddress"
df_salesltcustomeraddress.write.mode("overwrite").format("delta").save(basePathSilverLakeHouse + '//' + tableName)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 18, Finished, Available, Finished)

# %%
tableName="salesProduct"
df_salesltproduct.write.mode("overwrite").format("delta").save(basePathSilverLakeHouse + '//' + tableName)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 19, Finished, Available, Finished)

# %%
tableName="salesProductCategory"
df_salesltproductcategory.write.mode("overwrite").format("delta").save(basePathSilverLakeHouse + '//' + tableName)
# Out:
# StatementMeta(, 3392b31d-b97c-4cfd-9d68-d964dd9df541, 20, Finished, Available, Finished)
